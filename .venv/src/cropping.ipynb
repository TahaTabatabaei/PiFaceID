# %%
import tensorflow as tf
import numpy as np
from functions import *

# %%
import os
root = "E:/taha/code/ras-face/.venv/src"

# face detection for the apa Dataset
dir = root + "/dataset/apa-dataset/train/"
cropDir = root + "/dataset/apa-dataset/crop/train/"
crop = root + "/dataset/apa-dataset/crop/"

if not os.path.exists(crop):
    os.mkdir(root + "/dataset/apa-dataset/crop/")

# load train dataset
if not os.path.exists(cropDir):
    os.mkdir(root + "/dataset/apa-dataset/crop/train/")
trainX, trainy = load_dataset(dir, cropDir)
print(trainX.shape, trainy.shape)

# load test dataset
dir = root + "/dataset/myImages/test/"
cropDir = root + "/dataset/apa-dataset/crop/test/"

if not os.path.exists(cropDir):
    os.mkdir(root + "/dataset/apa-dataset/crop/test/")
testX, testy = load_dataset(dir, cropDir)

# save arrays to one file in compressed format
#np.savez_compressed('myImages.npz', trainX, trainy, testX, testy)
# Out:
# ...
# 1/1 [==============================] - 0s 354ms/step
# E:/taha/code/ras-face/.venv/src/dataset/apa-dataset/crop/train/Ali_Hajghani/photo_10_2023-10-11_16-44-44-cropped.jpg
# 1/1 [==============================] - 0s 363ms/step
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001BB0506EB00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 1/1 [==============================] - 0s 363ms/step
# ...
